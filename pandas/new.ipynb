# %%
import pandas as pd

# %%
info = {
    "name": ['fawaz','faaiz','fawzan'],
    "cgpa":[9,8,6]
}

# %%
df = pd.DataFrame(info,index=['superman','gaynigger','hielhitler'])
df
# Out:
#      name  cgpa
# 0   fawaz     9
# 1   faaiz     8
# 2  fawzan     6
